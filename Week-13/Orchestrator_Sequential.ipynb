# %% [markdown]
# Call Notebook 1

# %%
dbutils.notebook.run("Notebook-01", 0)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-2186025231683525>, line 1
# ----> 1 dbutils.notebook.run("Notebook-01", 0)
#
# File /databricks/python_shell/dbruntime/dbutils.py:278, in DBUtils.NotebookHandler.run(self, path, timeout_seconds, arguments, *args, **kwargs)
#     276 arguments_scala_map: Dict[str, str]
#     277 arguments_scala_map = self.sc._jvm.PythonUtils.toScalaMap(arguments)  # type: ignore
# --> 278 return self.entry_point.getDbutils().notebook().run(
#     279     path, timeout_seconds, arguments_scala_map, __databricks_internal_cluster_spec)
#
# File /databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1355, in JavaMember.__call__(self, *args)
#    1349 command = proto.CALL_COMMAND_NAME +\
#    1350     self.command_header +\
#    1351     args_command +\
#    1352     proto.END_COMMAND_PART
# ...

# %% [markdown]
# Call Notebook 2

# %%
dbutils.notebook.run("Notebook-02", 0)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-2186025231683529>, line 1
# ----> 1 dbutils.notebook.run("Notebook-02", 0)
#
# File /databricks/python_shell/dbruntime/dbutils.py:278, in DBUtils.NotebookHandler.run(self, path, timeout_seconds, arguments, *args, **kwargs)
#     276 arguments_scala_map: Dict[str, str]
#     277 arguments_scala_map = self.sc._jvm.PythonUtils.toScalaMap(arguments)  # type: ignore
# --> 278 return self.entry_point.getDbutils().notebook().run(
#     279     path, timeout_seconds, arguments_scala_map, __databricks_internal_cluster_spec)
#
# File /databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1355, in JavaMember.__call__(self, *args)
#    1349 command = proto.CALL_COMMAND_NAME +\
#    1350     self.command_header +\
#    1351     args_command +\
#    1352     proto.END_COMMAND_PART
# ...

# %% [markdown]
# Call Notebook 3

# %%
dbutils.notebook.run("Notebook-03", 0)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# File <command-2186025231683531>, line 1
# ----> 1 dbutils.notebook.run("Notebook-03", 0)
#
# File /databricks/python_shell/dbruntime/dbutils.py:278, in DBUtils.NotebookHandler.run(self, path, timeout_seconds, arguments, *args, **kwargs)
#     276 arguments_scala_map: Dict[str, str]
#     277 arguments_scala_map = self.sc._jvm.PythonUtils.toScalaMap(arguments)  # type: ignore
# --> 278 return self.entry_point.getDbutils().notebook().run(
#     279     path, timeout_seconds, arguments_scala_map, __databricks_internal_cluster_spec)
#
# File /databricks/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1355, in JavaMember.__call__(self, *args)
#    1349 command = proto.CALL_COMMAND_NAME +\
#    1350     self.command_header +\
#    1351     args_command +\
#    1352     proto.END_COMMAND_PART
# ...

# %% [markdown]
# Call Notebook 4

# %%
dbutils.notebook.run("Notebook-04", 0)
